# %% [markdown]
# ## Reporting: Getting all (historical) Orders and Trades

# %%
# importing binance and pandas
from binance.client import Client
import pandas as pd

# getting the testnet api keys
keys_test = pd.read_csv("~/Documents/temp/bnc/testnet_key.txt", sep=" ", header=None)
api_key_test = keys_test[0][0]
secret_key_test = keys_test[0][1]

# use your testnet credentials with testnet = True
client = Client(api_key = api_key_test, api_secret = secret_key_test, tld = "com", testnet = True)

# %%
client.get_account()
# Out:
# {'makerCommission': 0,
#  'takerCommission': 0,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': False,
#  'canDeposit': False,
#  'updateTime': 1654520497772,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BNB',
#    'free': '1000.00000000',
#    'locked': '0.00000000'},
#   {'asset': 'BTC', 'free': '1.21383800', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '10000.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '100.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '500.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '500000.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '3315.13509034', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '50000.00000000', 'locked': '0.00000000'}],
#  'permissions': ['SPOT']}

# %%
all_orders = client.get_all_orders(symbol = "BTCUSDT")
all_orders
# Out:
# [{'symbol': 'BTCUSDT',
#   'orderId': 13491958,
#   'orderListId': -1,
#   'clientOrderId': 'vvbKXE6XtX61QlfYce4kl2',
#   'price': '0.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.10000000',
#   'cummulativeQuoteQty': '3126.20181204',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'MARKET',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654500932175,
#   'updateTime': 1654500932175,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13492243,
#   'orderListId': -1,
#   'clientOrderId': 'qeFOTdoBExVDhCE6YHyPTY',
#   'price': '0.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.10000000',
#   'cummulativeQuoteQty': '3124.97307839',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'MARKET',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654501001046,
#   'updateTime': 1654501001046,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13506019,
#   'orderListId': -1,
#   'clientOrderId': '51esvAzbpPiC0VXQD2ZNBd',
#   'price': '0.00000000',
#   'origQty': '0.03184900',
#   'executedQty': '0.03184900',
#   'cummulativeQuoteQty': '999.97738505',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'MARKET',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654504293800,
#   'updateTime': 1654504293800,
#   'isWorking': True,
#   'origQuoteOrderQty': '1000.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13508333,
#   'orderListId': -1,
#   'clientOrderId': 'pOQuO53muYqSPtTkpuyZnw',
#   'price': '0.00000000',
#   'origQty': '0.11801100',
#   'executedQty': '0.11801100',
#   'cummulativeQuoteQty': '3707.78481878',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'MARKET',
#   'side': 'SELL',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654504850947,
#   'updateTime': 1654504850947,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13562133,
#   'orderListId': -1,
#   'clientOrderId': 'xeJOL8sx8UJu8HnTsaWJGG',
#   'price': '50000.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.10000000',
#   'cummulativeQuoteQty': '3141.49745296',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654517718832,
#   'updateTime': 1654517718832,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13563456,
#   'orderListId': -1,
#   'clientOrderId': 'DF7fxTvLggxoJZMOOpAWWY',
#   'price': '28243.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654518039513,
#   'updateTime': 1654519934179,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13565583,
#   'orderListId': -1,
#   'clientOrderId': 'SR9fpWmkqoSLKXGDmuqC38',
#   'price': '28272.00000000',
#   'origQty': '0.01000000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654518548701,
#   'updateTime': 1654519873920,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13567594,
#   'orderListId': -1,
#   'clientOrderId': '1ML1sIrY3k2LbqmzAGhHAN',
#   'price': '34579.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'SELL',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654519018363,
#   'updateTime': 1654519940797,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13570961,
#   'orderListId': -1,
#   'clientOrderId': '4ahbwMsm7FEkiEFzinT1hr',
#   'price': '34563.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'SELL',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654519786987,
#   'updateTime': 1654519901255,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13573689,
#   'orderListId': -1,
#   'clientOrderId': 'AruxwgWteO6BhGRAYRQtBM',
#   'price': '28265.00000000',
#   'origQty': '0.01000000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654520425909,
#   'updateTime': 1654520494683,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 13573810,
#   'orderListId': -1,
#   'clientOrderId': 'JFNX7brYhoCfViQlsqODUy',
#   'price': '34531.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'SELL',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1654520450155,
#   'updateTime': 1654520497772,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'}]

# %%
df = pd.DataFrame(all_orders)
df
# Out:
#      symbol   orderId  orderListId           clientOrderId           price  \
# 0   BTCUSDT  13491958           -1  vvbKXE6XtX61QlfYce4kl2      0.00000000
# 1   BTCUSDT  13492243           -1  qeFOTdoBExVDhCE6YHyPTY      0.00000000
# 2   BTCUSDT  13506019           -1  51esvAzbpPiC0VXQD2ZNBd      0.00000000
# 3   BTCUSDT  13508333           -1  pOQuO53muYqSPtTkpuyZnw      0.00000000
# 4   BTCUSDT  13562133           -1  xeJOL8sx8UJu8HnTsaWJGG  50000.00000000
# 5   BTCUSDT  13563456           -1  DF7fxTvLggxoJZMOOpAWWY  28243.00000000
# 6   BTCUSDT  13565583           -1  SR9fpWmkqoSLKXGDmuqC38  28272.00000000
# 7   BTCUSDT  13567594           -1  1ML1sIrY3k2LbqmzAGhHAN  34579.00000000
# 8   BTCUSDT  13570961           -1  4ahbwMsm7FEkiEFzinT1hr  34563.00000000
# 9   BTCUSDT  13573689           -1  AruxwgWteO6BhGRAYRQtBM  28265.00000000
# 10  BTCUSDT  13573810           -1  JFNX7brYhoCfViQlsqODUy  34531.00000000
#
#        origQty executedQty cummulativeQuoteQty    status timeInForce    type  \
# 0   0.10000000  0.10000000       3126.20181204    FILLED         GTC  MARKET
# 1   0.10000000  0.10000000       3124.97307839    FILLED         GTC  MARKET
# 2   0.03184900  0.03184900        999.97738505    FILLED         GTC  MARKET
# 3   0.11801100  0.11801100       3707.78481878    FILLED         GTC  MARKET
# 4   0.10000000  0.10000000       3141.49745296    FILLED         GTC   LIMIT
# 5   0.10000000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
# 6   0.01000000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
# 7   0.10000000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
# 8   0.10000000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
# 9   0.01000000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
# 10  0.10000000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
#
#     side   stopPrice  icebergQty           time     updateTime  isWorking  \
# 0    BUY  0.00000000  0.00000000  1654500932175  1654500932175       True
# 1    BUY  0.00000000  0.00000000  1654501001046  1654501001046       True
# 2    BUY  0.00000000  0.00000000  1654504293800  1654504293800       True
# 3   SELL  0.00000000  0.00000000  1654504850947  1654504850947       True
# 4    BUY  0.00000000  0.00000000  1654517718832  1654517718832       True
# 5    BUY  0.00000000  0.00000000  1654518039513  1654519934179       True
# 6    BUY  0.00000000  0.00000000  1654518548701  1654519873920       True
# 7   SELL  0.00000000  0.00000000  1654519018363  1654519940797       True
# 8   SELL  0.00000000  0.00000000  1654519786987  1654519901255       True
# 9    BUY  0.00000000  0.00000000  1654520425909  1654520494683       True
# 10  SELL  0.00000000  0.00000000  1654520450155  1654520497772       True
#
#    origQuoteOrderQty
# 0         0.00000000
# 1         0.00000000
# 2      1000.00000000
# 3         0.00000000
# 4         0.00000000
# 5         0.00000000
# 6         0.00000000
# 7         0.00000000
# 8         0.00000000
# 9         0.00000000
# 10        0.00000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symbol               11 non-null     object
#  1   orderId              11 non-null     int64
#  2   orderListId          11 non-null     int64
#  3   clientOrderId        11 non-null     object
#  4   price                11 non-null     object
#  5   origQty              11 non-null     object
#  6   executedQty          11 non-null     object
#  7   cummulativeQuoteQty  11 non-null     object
#  8   status               11 non-null     object
#  9   timeInForce          11 non-null     object
#  10  type                 11 non-null     object
#  11  side                 11 non-null     object
#  12  stopPrice            11 non-null     object
#  13  icebergQty           11 non-null     object
#  14  time                 11 non-null     int64
#  15  updateTime           11 non-null     int64
#  16  isWorking            11 non-null     bool
#  17  origQuoteOrderQty    11 non-null     object
# dtypes: bool(1), int64(4), object(13)
# memory usage: 1.6+ KB

# %%
trades = client.get_my_trades(symbol = "BTCUSDT")
trades
# Out:
# [{'symbol': 'BTCUSDT',
#   'id': 5282947,
#   'orderId': 13491958,
#   'orderListId': -1,
#   'price': '31262.00000000',
#   'qty': '0.05469900',
#   'quoteQty': '1710.00013800',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1654500932175,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5282948,
#   'orderId': 13491958,
#   'orderListId': -1,
#   'price': '31262.04000000',
#   'qty': '0.04530100',
#   'quoteQty': '1416.20167404',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1654500932175,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5283090,
#   'orderId': 13492243,
#   'orderListId': -1,
#   'price': '31249.73000000',
#   'qty': '0.09216100',
#   'quoteQty': '2880.00636653',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1654501001046,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5283091,
#   'orderId': 13492243,
#   'orderListId': -1,
#   'price': '31249.74000000',
#   'qty': '0.00783900',
#   'quoteQty': '244.96671186',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1654501001046,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5288155,
#   'orderId': 13506019,
#   'orderListId': -1,
#   'price': '31397.45000000',
#   'qty': '0.03184900',
#   'quoteQty': '999.97738505',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1654504293800,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5289003,
#   'orderId': 13508333,
#   'orderListId': -1,
#   'price': '31419.00000000',
#   'qty': '0.06333800',
#   'quoteQty': '1990.01662200',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1654504850947,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5289004,
#   'orderId': 13508333,
#   'orderListId': -1,
#   'price': '31418.95000000',
#   'qty': '0.04901600',
#   'quoteQty': '1540.03125320',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1654504850947,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5289005,
#   'orderId': 13508333,
#   'orderListId': -1,
#   'price': '31418.94000000',
#   'qty': '0.00565700',
#   'quoteQty': '177.73694358',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1654504850947,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5308008,
#   'orderId': 13562133,
#   'orderListId': -1,
#   'price': '31414.96000000',
#   'qty': '0.05156800',
#   'quoteQty': '1620.00665728',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1654517718832,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 5308009,
#   'orderId': 13562133,
#   'orderListId': -1,
#   'price': '31414.99000000',
#   'qty': '0.04843200',
#   'quoteQty': '1521.49079568',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1654517718832,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True}]

# %%
df_trades = pd.DataFrame(trades)
df_trades
# Out:
#     symbol       id   orderId  orderListId           price         qty  \
# 0  BTCUSDT  5282947  13491958           -1  31262.00000000  0.05469900
# 1  BTCUSDT  5282948  13491958           -1  31262.04000000  0.04530100
# 2  BTCUSDT  5283090  13492243           -1  31249.73000000  0.09216100
# 3  BTCUSDT  5283091  13492243           -1  31249.74000000  0.00783900
# 4  BTCUSDT  5288155  13506019           -1  31397.45000000  0.03184900
# 5  BTCUSDT  5289003  13508333           -1  31419.00000000  0.06333800
# 6  BTCUSDT  5289004  13508333           -1  31418.95000000  0.04901600
# 7  BTCUSDT  5289005  13508333           -1  31418.94000000  0.00565700
# 8  BTCUSDT  5308008  13562133           -1  31414.96000000  0.05156800
# 9  BTCUSDT  5308009  13562133           -1  31414.99000000  0.04843200
#
#         quoteQty  commission commissionAsset           time  isBuyer  isMaker  \
# 0  1710.00013800  0.00000000             BTC  1654500932175     True    False
# 1  1416.20167404  0.00000000             BTC  1654500932175     True    False
# 2  2880.00636653  0.00000000             BTC  1654501001046     True    False
# 3   244.96671186  0.00000000             BTC  1654501001046     True    False
# 4   999.97738505  0.00000000             BTC  1654504293800     True    False
# 5  1990.01662200  0.00000000            USDT  1654504850947    False    False
# 6  1540.03125320  0.00000000            USDT  1654504850947    False    False
# 7   177.73694358  0.00000000            USDT  1654504850947    False    False
# 8  1620.00665728  0.00000000             BTC  1654517718832     True    False
# 9  1521.49079568  0.00000000             BTC  1654517718832     True    False
#
#    isBestMatch
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True

# %%
df_trades.time = pd.to_datetime(df.time, unit = "ms", errors = "coerce")
df_trades
# Out:
#     symbol       id   orderId  orderListId           price         qty  \
# 0  BTCUSDT  5282947  13491958           -1  31262.00000000  0.05469900
# 1  BTCUSDT  5282948  13491958           -1  31262.04000000  0.04530100
# 2  BTCUSDT  5283090  13492243           -1  31249.73000000  0.09216100
# 3  BTCUSDT  5283091  13492243           -1  31249.74000000  0.00783900
# 4  BTCUSDT  5288155  13506019           -1  31397.45000000  0.03184900
# 5  BTCUSDT  5289003  13508333           -1  31419.00000000  0.06333800
# 6  BTCUSDT  5289004  13508333           -1  31418.95000000  0.04901600
# 7  BTCUSDT  5289005  13508333           -1  31418.94000000  0.00565700
# 8  BTCUSDT  5308008  13562133           -1  31414.96000000  0.05156800
# 9  BTCUSDT  5308009  13562133           -1  31414.99000000  0.04843200
#
#         quoteQty  commission commissionAsset                    time  isBuyer  \
# 0  1710.00013800  0.00000000             BTC 2022-06-06 07:35:32.175     True
# 1  1416.20167404  0.00000000             BTC 2022-06-06 07:36:41.046     True
# 2  2880.00636653  0.00000000             BTC 2022-06-06 08:31:33.800     True
# 3   244.96671186  0.00000000             BTC 2022-06-06 08:40:50.947     True
# 4   999.97738505  0.00000000             BTC 2022-06-06 12:15:18.832     True
# 5  1990.01662200  0.00000000            USDT 2022-06-06 12:20:39.513    False
# 6  1540.03125320  0.00000000            USDT 2022-06-06 12:29:08.701    False
# 7   177.73694358  0.00000000            USDT 2022-06-06 12:36:58.363    False
# 8  1620.00665728  0.00000000             BTC 2022-06-06 12:49:46.987     True
# 9  1521.49079568  0.00000000             BTC 2022-06-06 13:00:25.909     True
#
#    isMaker  isBestMatch
# 0    False         True
# 1    False         True
# 2    False         True
# 3    False         True
# 4    False         True
# 5    False         True
# 6    False         True
# 7    False         True
# 8    False         True
# 9    False         True
